# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
import time

b = 150
m = -127.82
all_b = []
all_m = []
all_cost = []
all_lr = []


epochs = 1

start = time.time()

t0,t1 = 5,50
def learning_rate(t):
    return t0/(t + t1)

for i in range(epochs):
    for j in range(X.shape[0]):
        
        lr = learning_rate(i * X.shape[0] + j)
        
        idx = np.random.randint(X.shape[0], size=1)
        
        slope_b = -2 * (y[idx] - (m * X[idx]) -  b)
        slope_m = -2 * (y[idx] - (m * X[idx]) -  b) * X[idx]
        cost = (y[idx] - m * X[idx] -b) ** 2
        
        
        b = b - (lr * slope_b)
        m = m - (lr * slope_m)
        all_b.append(b)
        all_m.append(m)
        all_cost.append(cost)
        all_lr.append(lr)
print("Total time taken",time.time() - start)
# Out:
# Total time taken 0.02033400535583496

# %%
len(all_cost)
# Out:
# 100

# %%
fig, ax = plt.subplots(figsize=(9,5))
#fig.set_tight_layout(True)

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*(-27) -150
ax.scatter(X, y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*all_m[i] + all_b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, frames=100, interval=5)

f = r"stochastic_animation_line_plot.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
m_arr = np.linspace(-150, 150, 10)
b_arr = np.linspace(-150, 150, 10)
mGrid, bGrid = np.meshgrid(m_arr,b_arr)

final = np.vstack((mGrid.ravel().reshape(1,100),bGrid.ravel().reshape(1,100))).T

z_arr = []

for i in range(final.shape[0]):
    z_arr.append(np.sum((y - final[i,0]*X.reshape(100) - final[i,1])**2))

z_arr = np.array(z_arr).reshape(10,10)

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(-150, 150), ylim =(-150, 150)) 

axis.contourf(m_arr, b_arr, z_arr)

line, = axis.plot([], [], lw = 2,color='white') 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(all_m[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 100,repeat=False, interval = 100)

#f = r"stochastic_animation_contour_plot.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 7
#       5 # intercept graph
#       6 num_epochs = list(range(0,30))
# ----> 7 fig = plt.figure(figsize=(9,5))
#       8 axis = plt.axes(xlim =(-150, 150), ylim =(-150, 150))
#      10 axis.contourf(m_arr, b_arr, z_arr)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:3396, in _Backend.new_figure_manager(cls, num, *args, **kwargs)
#    3394 fig_cls = kwargs.pop('FigureClass', Figure)
#    3395 fig = fig_cls(*args, **kwargs)
# -> 3396 return cls.new_figure_manager_given_figure(num, fig)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:3401, in _Backend.new_figure_manager_given_figure(cls, num, figure)
#    3398 @classmethod
#    3399 def new_figure_manager_given_figure(cls, num, figure):
#    3400     """Create a new figure manager instance for the given figure."""
# -> 3401     return cls.FigureCanvas.new_manager(figure, num)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1785, in FigureCanvasBase.new_manager(cls, figure, num)
#    1774 @classmethod
#    1775 def new_manager(cls, figure, num):
#    1776     """
#    1777     Create a new figure manager for *figure*, using this canvas class.
#    1778
#    (...)
#    1783     ``FigureManager.create_with_canvas``.
#    1784     """
# -> 1785     return cls.manager_class.create_with_canvas(cls, figure, num)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_nbagg.py:74, in FigureManagerNbAgg.create_with_canvas(cls, canvas_class, figure, num)
#      71 @classmethod
#      72 def create_with_canvas(cls, canvas_class, figure, num):
#      73     canvas = canvas_class(figure)
# ---> 74     manager = cls(canvas, num)
#      75     if is_interactive():
#      76         manager.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_nbagg.py:69, in FigureManagerNbAgg.__init__(self, canvas, num)
#      67 def __init__(self, canvas, num):
#      68     self._shown = False
# ---> 69     super().__init__(canvas, num)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py:432, in FigureManagerWebAgg.__init__(self, canvas, num)
#     430 def __init__(self, canvas, num):
#     431     self.web_sockets = set()
# --> 432     super().__init__(canvas, num)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2654, in FigureManagerBase.__init__(self, canvas, num)
#    2649 self.toolmanager = (ToolManager(canvas.figure)
#    2650                     if mpl.rcParams['toolbar'] == 'toolmanager'
#    2651                     else None)
#    2652 if (mpl.rcParams["toolbar"] == "toolbar2"
#    2653         and self._toolbar2_class):
# -> 2654     self.toolbar = self._toolbar2_class(self.canvas)
#    2655 elif (mpl.rcParams["toolbar"] == "toolmanager"
#    2656         and self._toolmanager_toolbar_class):
#    2657     self.toolbar = self._toolmanager_toolbar_class(self.toolmanager)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py:392, in NavigationToolbar2WebAgg.__init__(self, canvas)
#     390 def __init__(self, canvas):
#     391     self.message = ''
# --> 392     super().__init__(canvas)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2844, in NavigationToolbar2.__init__(self, canvas)
#    2842 self.canvas = canvas
#    2843 canvas.toolbar = self
# -> 2844 self._nav_stack = cbook._Stack()
#    2845 # This cursor will be set after the initial draw.
#    2846 self._last_cursor = tools.Cursors.POINTER
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_Stack'

# %%
all_b[-1]

# %%
all_m[-1]

# %%
num_epochs = list(range(0,100))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(0, 175000)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_cost[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 100,repeat=False, interval = 150)

f = r"stochastic_animation_cost_plot.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
import numpy as np
import matplotlib.pyplot as plt


fig,ax=plt.subplots(1,1)
plt.figure(figsize=(18,4))
cp = ax.contourf(m_arr, b_arr, z_arr)
ax.plot(np.array(all_m).ravel(),np.array(all_b).ravel(),color='white')
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
ax.set_xlabel('m')
ax.set_ylabel('b')
plt.show()

# %%
all_lr[0]

# %%
all_lr[-1]
